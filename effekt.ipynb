# %% [markdown]
# # Effekt
#
# Her skal der være en intro til effekt.

# %% [markdown]
# Her kommer formlen:
#
# $P = \frac{E}{t}$

# %% [markdown]
# ## Opgaver
#
# Her kommer en masse fine opgaver om effekt
